# %%
import json

# Define the file path
json_path = '/content/drive/MyDrive/annotation data/data_for_1-20.json'

# %%
# Open and read the JSON file
with open(json_path, 'r') as json_file:
    data = json.load(json_file)

# Now, 'data' contains the contents of the JSON file

# %%
# labels ::
# 1.0 PER
# 2.0 ORG
# 3.0 LOC
# 4.0 MISC
# 5.0 Date
# 6.0 Author
# 7.0 Co-author
# 8.0 Topic
# 9.0 Degree
# 10.0 University
# 11.0 Journal
# 12.0 Web-link
# 13.0 Designation
# 14.0 Email
# 15.0 Specialization
# 16.0 Advisor
# 17.0 Conference
# 18.0 Phone number
# 19.0 Fax number
# 20.0 Expertise
# 21.0 Title

# %%
print(type(data))

print(len(data))



print(type(data[0]))

print(data[0].keys())
# Out:
# <class 'list'>
# 20
# <class 'dict'>
# dict_keys(['annotations', 'drafts', 'predictions', 'data', 'meta'])

# %%
print(type(data[0]['annotations']))
print(type(data[0]['drafts']))
print(type(data[0]['predictions']))

print(type(data[0]['data']))
print(type(data[0]['meta']))


print(data[0].keys())


print(len(data[0]['annotations']))
print(len(data[0]['drafts']))
print(len(data[0]['predictions']))

print(len(data[0]['data']))
print(len(data[0]['meta']))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'dict'>
# <class 'dict'>
# dict_keys(['annotations', 'drafts', 'predictions', 'data', 'meta'])
# 1
# 0
# 0
# 1
# 2

# %%
print(type(data[0]['annotations']))

print(len(data[0]['annotations']))



print(type(data[0]['annotations'][0]))

print(data[0]['annotations'][0].keys())
# Out:
# <class 'list'>
# 1
# <class 'dict'>
# dict_keys(['completed_by', 'result', 'was_cancelled', 'ground_truth', 'created_at', 'updated_at', 'lead_time', 'prediction', 'result_count', 'parent_prediction', 'parent_annotation'])

# %%
data[0]['annotations'][0]
# Out:
# {'completed_by': {'username': 'sayed0405035',
#   'first_name': 'Md',
#   'last_name': 'Sayeduzzaman',
#   'avatar': 'https://dagshub.com/avatars/29118'},
#  'result': [{'id': 'HPMwAwxzRr',
#    'type': 'labels',
#    'value': {'end': 13,
#     'text': 'Zhang, L.',
#     'start': 4,
#     'labels': ['Co-author']},
#    'origin': 'manual',
#    'to_name': 'text',
#    'from_name': 'label'},
#   {'id': 'K0RatyLhY1',
#    'type': 'labels',
#    'value': {'end': 20, 'text': 'H. Li', 'start': 15, 'labels': ['Co-author']},
#    'origin': 'manual',
#    'to_name': 'text',
#    'from_name': 'label'},
#   {'id': 'cnPOmxtpBr',
#    'type': 'labels',
#    'value': {'end': 27, 'text': 'S. Li', 'start': 22, 'labels': ['Co-author']},
#    'origin': 'manual',
#    'to_name': 'text',
#    'from_name': 'label'},
#   {'id': '6AGniyIsWZ',
#    'type': 'labels',
#    'value': {'end': 38,
#     'text': 'A. Zha ng',
#     'start': 29,
#     'labels': ['Co-author']},
#    'origin': 'manual',
# ...

# %%
for item in data[0]['annotations'][0].keys():
    print(item," :: ",type(data[0]['annotations'][0][item]))
    print("*****************************")
# Out:
# completed_by  ::  <class 'dict'>
# *****************************
# result  ::  <class 'list'>
# *****************************
# was_cancelled  ::  <class 'bool'>
# *****************************
# ground_truth  ::  <class 'bool'>
# *****************************
# created_at  ::  <class 'str'>
# *****************************
# updated_at  ::  <class 'str'>
# *****************************
# lead_time  ::  <class 'float'>
# *****************************
# prediction  ::  <class 'dict'>
# *****************************
# result_count  ::  <class 'int'>
# *****************************
# parent_prediction  ::  <class 'NoneType'>
# *****************************
# parent_annotation  ::  <class 'NoneType'>
# *****************************

# %%
data[0]['annotations'][0].keys()
# Out:
# dict_keys(['completed_by', 'result', 'was_cancelled', 'ground_truth', 'created_at', 'updated_at', 'lead_time', 'prediction', 'result_count', 'parent_prediction', 'parent_annotation'])

# %%
print(len(data[0]['annotations'][0]['result']))


print(data[0]['annotations'][0]['result'][10])

print(data[0]['annotations'][0]['result'][30])
# Out:
# 92
# {'id': '7V8zd_fACa', 'type': 'labels', 'value': {'end': 103, 'text': 'D.  H. Gouge', 'start': 91, 'labels': ['Author']}, 'origin': 'manual', 'to_name': 'text', 'from_name': 'label'}
# {'id': 'OSesE7msno', 'type': 'labels', 'value': {'end': 817, 'text': 'Gouge, D. H.', 'start': 805, 'labels': ['Author']}, 'origin': 'manual', 'to_name': 'text', 'from_name': 'label'}

# %%
data[0]['drafts']
# Out:
# []

# %%
data[0]['predictions']
# Out:
# []

# %%
data[0]['data'].keys()
# Out:
# dict_keys(['text'])

# %%
data[0]['meta']
# Out:
# {'line': 12,
#  'original_data': {'$undefined$': 'repo://e6909173258bd96605d208156b63c409ba7ac7f2/data/CURRICULUM-VITAE_DHG_012519.txt'}}

# %%
for item in data:
    print(type(item))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
